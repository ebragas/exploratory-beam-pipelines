# %%
import os
import json
import apache_beam as beam
from apache_beam.options.pipeline_options import PipelineOptions
from apache_beam.options.pipeline_options import GoogleCloudOptions
from apache_beam.options.pipeline_options import StandardOptions
from apache_beam.runners.interactive.interactive_runner import InteractiveRunner
import apache_beam.runners.interactive.interactive_beam as ib
import google.auth

# %%
PROJECT_ID = "beam-udemy"
TOPIC_ID = "beam-example-input"
SUBSCRIPTION_ID = "beam-example-input-sub1"

# %%
options = PipelineOptions()

options.view_as(StandardOptions).streaming = True

_, options.view_as(GoogleCloudOptions).project = google.auth.default()

# %%
ib.options.recording_duration = '2m'
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div class="alert alert-info">You have changed recording duration from 60.0 seconds to 120.0 seconds. To allow new data to be recorded for the updated duration the next time a PCollection is evaluated or the pipeline is executed, please invoke ib.recordings.stop, ib.recordings.clear and ib.recordings.record.</div>

# %%
p = beam.Pipeline(InteractiveRunner(), options=options)

# %%
data = p | "read" >> beam.io.ReadFromPubSub(topic=f"projects/{PROJECT_ID}/topics/{TOPIC_ID}")

# %%
# ib.recordings.clear(p)

ib.show(data)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_8b87d43d43a1877d2e9800a3e6daba6d" class="spinner-border text-info" role="status">
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_be20d4d925a258dd11e8d40df0fd5aa5" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_be20d4d925a258dd11e8d40df0fd5aa5")) {
#               dt = $("#table_df_be20d4d925a258dd11e8d40df0fd5aa5").dataTable();
#             } else if ($("#table_df_be20d4d925a258dd11e8d40df0fd5aa5_wrapper").length == 0) {
#               dt = $("#table_df_be20d4d925a258dd11e8d40df0fd5aa5").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'data.0'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'b\'{"name": "Charles Reynolds", "address": "936 Maria Dale Suite 621\\\\nNew Jenniferfurt, NJ 59452", "transaction_amt": 96.13}\'', 0: 0}, {1: 'b\'{"name": "David Wright", "address": "238 Darlene Stravenue\\\\nThompsonland, UT 59429", "transaction_amt": 8.64}\'', 0: 1}, {1: 'b\'{"name": "Nicole Adams", "address": "USS Cowan\\\\nFPO AA 07913", "transaction_amt": 96.86}\'', 0: 2}, {1: 'b\'{"name": "Debbie Sampson", "address": "9067 Alexander Burg\\\\nMorrisonfurt, FL 62082", "transaction_amt": 88.24}\'', 0: 3}, {1: 'b\'{"name": "Renee Spencer", "address": "9130 Chang Mills\\\\nRileyberg, IN 14668", "transaction_amt": 11.75}\'', 0: 4}, {1: 'b\'{"name": "Frank Washington", "address": "USNV Brown\\\\nFPO AA 51094", "transaction_amt": 28.82}\'', 0: 5}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_be20d4d925a258dd11e8d40df0fd5aa5")) {
#               dt = $("#table_df_be20d4d925a258dd11e8d40df0fd5aa5").dataTable();
#             } else if ($("#table_df_be20d4d925a258dd11e8d40df0fd5aa5_wrapper").length == 0) {
#               dt = $("#table_df_be20d4d925a258dd11e8d40df0fd5aa5").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'data.0'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'b\'{"name": "Charles Reynolds", "address": "936 Maria Dale Suite 621\\\\nNew Jenniferfurt, NJ 59452", "transaction_amt": 96.13}\'', 0: 0}, {1: 'b\'{"name": "David Wright", "address": "238 Darlene Stravenue\\\\nThompsonland, UT 59429", "transaction_amt": 8.64}\'', 0: 1}, {1: 'b\'{"name": "Nicole Adams", "address": "USS Cowan\\\\nFPO AA 07913", "transaction_amt": 96.86}\'', 0: 2}, {1: 'b\'{"name": "Debbie Sampson", "address": "9067 Alexander Burg\\\\nMorrisonfurt, FL 62082", "transaction_amt": 88.24}\'', 0: 3}, {1: 'b\'{"name": "Renee Spencer", "address": "9130 Chang Mills\\\\nRileyberg, IN 14668", "transaction_amt": 11.75}\'', 0: 4}, {1: 'b\'{"name": "Frank Washington", "address": "USNV Brown\\\\nFPO AA 51094", "transaction_amt": 28.82}\'', 0: 5}])
#               .draw('full-hold');
#           });
#         }
#             </script>

# %%
data_parsed = data | beam.Map(json.loads)

# %%
ib.show(data_parsed)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_721f1fb919734a71dbc7baaf889d52d9" class="spinner-border text-info" role="status">
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_8e59c9c23458fdc4b1999450dd709019" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_8e59c9c23458fdc4b1999450dd709019")) {
#               dt = $("#table_df_8e59c9c23458fdc4b1999450dd709019").dataTable();
#             } else if ($("#table_df_8e59c9c23458fdc4b1999450dd709019_wrapper").length == 0) {
#               dt = $("#table_df_8e59c9c23458fdc4b1999450dd709019").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'name'}, {'title': 'address'}, {'title': 'transaction_amt'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Charles Reynolds', 2: '936 Maria Dale Suite 621\nNew Jenniferfurt, NJ 59452', 3: '96.13', 0: 0}, {1: 'David Wright', 2: '238 Darlene Stravenue\nThompsonland, UT 59429', 3: '8.64', 0: 1}, {1: 'Nicole Adams', 2: 'USS Cowan\nFPO AA 07913', 3: '96.86', 0: 2}, {1: 'Debbie Sampson', 2: '9067 Alexander Burg\nMorrisonfurt, FL 62082', 3: '88.24', 0: 3}, {1: 'Renee Spencer', 2: '9130 Chang Mills\nRileyberg, IN 14668', 3: '11.75', 0: 4}, {1: 'Frank Washington', 2: 'USNV Brown\nFPO AA 51094', 3: '28.82', 0: 5}, {1: 'David Montoya', 2: '958 Thomas Streets Suite 287\nAndersonbury, HI 03880', 3: '26.2', 0: 6}, {1: 'David Graham', 2: '43668 Lopez Mall\nNorth Kimberlymouth, MI 52226', 3: '57.49', 0: 7}, {1: 'Richard White', 2: 'USNV Mitchell\nFPO AE 10736', 3: '97.67', 0: 8}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_8e59c9c23458fdc4b1999450dd709019")) {
#               dt = $("#table_df_8e59c9c23458fdc4b1999450dd709019").dataTable();
#             } else if ($("#table_df_8e59c9c23458fdc4b1999450dd709019_wrapper").length == 0) {
#               dt = $("#table_df_8e59c9c23458fdc4b1999450dd709019").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'name'}, {'title': 'address'}, {'title': 'transaction_amt'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Charles Reynolds', 2: '936 Maria Dale Suite 621\nNew Jenniferfurt, NJ 59452', 3: '96.13', 0: 0}, {1: 'David Wright', 2: '238 Darlene Stravenue\nThompsonland, UT 59429', 3: '8.64', 0: 1}, {1: 'Nicole Adams', 2: 'USS Cowan\nFPO AA 07913', 3: '96.86', 0: 2}, {1: 'Debbie Sampson', 2: '9067 Alexander Burg\nMorrisonfurt, FL 62082', 3: '88.24', 0: 3}, {1: 'Renee Spencer', 2: '9130 Chang Mills\nRileyberg, IN 14668', 3: '11.75', 0: 4}, {1: 'Frank Washington', 2: 'USNV Brown\nFPO AA 51094', 3: '28.82', 0: 5}, {1: 'David Montoya', 2: '958 Thomas Streets Suite 287\nAndersonbury, HI 03880', 3: '26.2', 0: 6}, {1: 'David Graham', 2: '43668 Lopez Mall\nNorth Kimberlymouth, MI 52226', 3: '57.49', 0: 7}, {1: 'Richard White', 2: 'USNV Mitchell\nFPO AE 10736', 3: '97.67', 0: 8}])
#               .draw('full-hold');
#           });
#         }
#             </script>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_8e59c9c23458fdc4b1999450dd709019" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_8e59c9c23458fdc4b1999450dd709019")) {
#               dt = $("#table_df_8e59c9c23458fdc4b1999450dd709019").dataTable();
#             } else if ($("#table_df_8e59c9c23458fdc4b1999450dd709019_wrapper").length == 0) {
#               dt = $("#table_df_8e59c9c23458fdc4b1999450dd709019").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'name'}, {'title': 'address'}, {'title': 'transaction_amt'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Charles Reynolds', 2: '936 Maria Dale Suite 621\nNew Jenniferfurt, NJ 59452', 3: '96.13', 0: 0}, {1: 'David Wright', 2: '238 Darlene Stravenue\nThompsonland, UT 59429', 3: '8.64', 0: 1}, {1: 'Nicole Adams', 2: 'USS Cowan\nFPO AA 07913', 3: '96.86', 0: 2}, {1: 'Debbie Sampson', 2: '9067 Alexander Burg\nMorrisonfurt, FL 62082', 3: '88.24', 0: 3}, {1: 'Renee Spencer', 2: '9130 Chang Mills\nRileyberg, IN 14668', 3: '11.75', 0: 4}, {1: 'Frank Washington', 2: 'USNV Brown\nFPO AA 51094', 3: '28.82', 0: 5}, {1: 'David Montoya', 2: '958 Thomas Streets Suite 287\nAndersonbury, HI 03880', 3: '26.2', 0: 6}, {1: 'David Graham', 2: '43668 Lopez Mall\nNorth Kimberlymouth, MI 52226', 3: '57.49', 0: 7}, {1: 'Richard White', 2: 'USNV Mitchell\nFPO AE 10736', 3: '97.67', 0: 8}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_8e59c9c23458fdc4b1999450dd709019")) {
#               dt = $("#table_df_8e59c9c23458fdc4b1999450dd709019").dataTable();
#             } else if ($("#table_df_8e59c9c23458fdc4b1999450dd709019_wrapper").length == 0) {
#               dt = $("#table_df_8e59c9c23458fdc4b1999450dd709019").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'name'}, {'title': 'address'}, {'title': 'transaction_amt'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Charles Reynolds', 2: '936 Maria Dale Suite 621\nNew Jenniferfurt, NJ 59452', 3: '96.13', 0: 0}, {1: 'David Wright', 2: '238 Darlene Stravenue\nThompsonland, UT 59429', 3: '8.64', 0: 1}, {1: 'Nicole Adams', 2: 'USS Cowan\nFPO AA 07913', 3: '96.86', 0: 2}, {1: 'Debbie Sampson', 2: '9067 Alexander Burg\nMorrisonfurt, FL 62082', 3: '88.24', 0: 3}, {1: 'Renee Spencer', 2: '9130 Chang Mills\nRileyberg, IN 14668', 3: '11.75', 0: 4}, {1: 'Frank Washington', 2: 'USNV Brown\nFPO AA 51094', 3: '28.82', 0: 5}, {1: 'David Montoya', 2: '958 Thomas Streets Suite 287\nAndersonbury, HI 03880', 3: '26.2', 0: 6}, {1: 'David Graham', 2: '43668 Lopez Mall\nNorth Kimberlymouth, MI 52226', 3: '57.49', 0: 7}, {1: 'Richard White', 2: 'USNV Mitchell\nFPO AE 10736', 3: '97.67', 0: 8}])
#               .draw('full-hold');
#           });
#         }
#             </script>

# %%
windowed = data_parsed | beam.WindowInto(beam.window.FixedWindows(10))

# %%
ib.show(windowed, include_window_info=True, visualize_data=True)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_42a8d62550be5ddce38a9c5632326cb7" class="spinner-border text-info" role="status">
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_e9f4d74381490052da85eac247e576af" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_e9f4d74381490052da85eac247e576af")) {
#               dt = $("#table_df_e9f4d74381490052da85eac247e576af").dataTable();
#             } else if ($("#table_df_e9f4d74381490052da85eac247e576af_wrapper").length == 0) {
#               dt = $("#table_df_e9f4d74381490052da85eac247e576af").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'name'}, {'title': 'address'}, {'title': 'transaction_amt'}, {'title': 'event_time'}, {'title': 'windows'}, {'title': 'pane_info'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Charles Reynolds', 2: '936 Maria Dale Suite 621\nNew Jenniferfurt, NJ 59452', 3: '96.13', 4: '2021-02-13 20:13:41.450000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 0}, {1: 'David Wright', 2: '238 Darlene Stravenue\nThompsonland, UT 59429', 3: '8.64', 4: '2021-02-13 20:13:43.162000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 1}, {1: 'Nicole Adams', 2: 'USS Cowan\nFPO AA 07913', 3: '96.86', 4: '2021-02-13 20:13:44.851000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 2}, {1: 'Debbie Sampson', 2: '9067 Alexander Burg\nMorrisonfurt, FL 62082', 3: '88.24', 4: '2021-02-13 20:13:46.463000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 3}, {1: 'Renee Spencer', 2: '9130 Chang Mills\nRileyberg, IN 14668', 3: '11.75', 4: '2021-02-13 20:13:48.083000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 4}, {1: 'Frank Washington', 2: 'USNV Brown\nFPO AA 51094', 3: '28.82', 4: '2021-02-13 20:13:49.765000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 5}, {1: 'David Montoya', 2: '958 Thomas Streets Suite 287\nAndersonbury, HI 03880', 3: '26.2', 4: '2021-02-13 20:13:51.455000+0000', 5: '2021-02-13 20:13:50.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 6}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_e9f4d74381490052da85eac247e576af")) {
#               dt = $("#table_df_e9f4d74381490052da85eac247e576af").dataTable();
#             } else if ($("#table_df_e9f4d74381490052da85eac247e576af_wrapper").length == 0) {
#               dt = $("#table_df_e9f4d74381490052da85eac247e576af").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'name'}, {'title': 'address'}, {'title': 'transaction_amt'}, {'title': 'event_time'}, {'title': 'windows'}, {'title': 'pane_info'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Charles Reynolds', 2: '936 Maria Dale Suite 621\nNew Jenniferfurt, NJ 59452', 3: '96.13', 4: '2021-02-13 20:13:41.450000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 0}, {1: 'David Wright', 2: '238 Darlene Stravenue\nThompsonland, UT 59429', 3: '8.64', 4: '2021-02-13 20:13:43.162000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 1}, {1: 'Nicole Adams', 2: 'USS Cowan\nFPO AA 07913', 3: '96.86', 4: '2021-02-13 20:13:44.851000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 2}, {1: 'Debbie Sampson', 2: '9067 Alexander Burg\nMorrisonfurt, FL 62082', 3: '88.24', 4: '2021-02-13 20:13:46.463000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 3}, {1: 'Renee Spencer', 2: '9130 Chang Mills\nRileyberg, IN 14668', 3: '11.75', 4: '2021-02-13 20:13:48.083000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 4}, {1: 'Frank Washington', 2: 'USNV Brown\nFPO AA 51094', 3: '28.82', 4: '2021-02-13 20:13:49.765000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 5}, {1: 'David Montoya', 2: '958 Thomas Streets Suite 287\nAndersonbury, HI 03880', 3: '26.2', 4: '2021-02-13 20:13:51.455000+0000', 5: '2021-02-13 20:13:50.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 6}])
#               .draw('full-hold');
#           });
#         }
#             </script>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#             <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
#             <facets-dive sprite-image-width="64" sprite-image-height="64" id="facets_dive_e9f4d74381490052da85eac247e576af" height="600"></facets-dive>
#             <script>
#               document.querySelector("#facets_dive_e9f4d74381490052da85eac247e576af").data = [];
#             </script>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#             <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
#             <facets-overview id="facets_overview_e9f4d74381490052da85eac247e576af"></facets-overview>
#             <script>
#               document.querySelector("#facets_overview_e9f4d74381490052da85eac247e576af").protoInput = "Cj4KBGRhdGEaEgoKZXZlbnRfdGltZRACIgIKABoPCgd3aW5kb3dzEAIiAgoAGhEKCXBhbmVfaW5mbxACIgIKAA==";
#             </script>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_e9f4d74381490052da85eac247e576af" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_e9f4d74381490052da85eac247e576af")) {
#               dt = $("#table_df_e9f4d74381490052da85eac247e576af").dataTable();
#             } else if ($("#table_df_e9f4d74381490052da85eac247e576af_wrapper").length == 0) {
#               dt = $("#table_df_e9f4d74381490052da85eac247e576af").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'name'}, {'title': 'address'}, {'title': 'transaction_amt'}, {'title': 'event_time'}, {'title': 'windows'}, {'title': 'pane_info'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Charles Reynolds', 2: '936 Maria Dale Suite 621\nNew Jenniferfurt, NJ 59452', 3: '96.13', 4: '2021-02-13 20:13:41.450000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 0}, {1: 'David Wright', 2: '238 Darlene Stravenue\nThompsonland, UT 59429', 3: '8.64', 4: '2021-02-13 20:13:43.162000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 1}, {1: 'Nicole Adams', 2: 'USS Cowan\nFPO AA 07913', 3: '96.86', 4: '2021-02-13 20:13:44.851000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 2}, {1: 'Debbie Sampson', 2: '9067 Alexander Burg\nMorrisonfurt, FL 62082', 3: '88.24', 4: '2021-02-13 20:13:46.463000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 3}, {1: 'Renee Spencer', 2: '9130 Chang Mills\nRileyberg, IN 14668', 3: '11.75', 4: '2021-02-13 20:13:48.083000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 4}, {1: 'Frank Washington', 2: 'USNV Brown\nFPO AA 51094', 3: '28.82', 4: '2021-02-13 20:13:49.765000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 5}, {1: 'David Montoya', 2: '958 Thomas Streets Suite 287\nAndersonbury, HI 03880', 3: '26.2', 4: '2021-02-13 20:13:51.455000+0000', 5: '2021-02-13 20:13:50.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 6}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_e9f4d74381490052da85eac247e576af")) {
#               dt = $("#table_df_e9f4d74381490052da85eac247e576af").dataTable();
#             } else if ($("#table_df_e9f4d74381490052da85eac247e576af_wrapper").length == 0) {
#               dt = $("#table_df_e9f4d74381490052da85eac247e576af").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'name'}, {'title': 'address'}, {'title': 'transaction_amt'}, {'title': 'event_time'}, {'title': 'windows'}, {'title': 'pane_info'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Charles Reynolds', 2: '936 Maria Dale Suite 621\nNew Jenniferfurt, NJ 59452', 3: '96.13', 4: '2021-02-13 20:13:41.450000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 0}, {1: 'David Wright', 2: '238 Darlene Stravenue\nThompsonland, UT 59429', 3: '8.64', 4: '2021-02-13 20:13:43.162000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 1}, {1: 'Nicole Adams', 2: 'USS Cowan\nFPO AA 07913', 3: '96.86', 4: '2021-02-13 20:13:44.851000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 2}, {1: 'Debbie Sampson', 2: '9067 Alexander Burg\nMorrisonfurt, FL 62082', 3: '88.24', 4: '2021-02-13 20:13:46.463000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 3}, {1: 'Renee Spencer', 2: '9130 Chang Mills\nRileyberg, IN 14668', 3: '11.75', 4: '2021-02-13 20:13:48.083000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 4}, {1: 'Frank Washington', 2: 'USNV Brown\nFPO AA 51094', 3: '28.82', 4: '2021-02-13 20:13:49.765000+0000', 5: '2021-02-13 20:13:40.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 5}, {1: 'David Montoya', 2: '958 Thomas Streets Suite 287\nAndersonbury, HI 03880', 3: '26.2', 4: '2021-02-13 20:13:51.455000+0000', 5: '2021-02-13 20:13:50.000000+0000 (10s)', 6: 'Pane 0: Final ', 0: 6}])
#               .draw('full-hold');
#           });
#         }
#             </script>

# %%
transactions = windowed | beam.Map(lambda e: e.get('transaction_amt'))

# %%
ib.show(transactions, include_window_info=True)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_a8864874ab4921550bceb88b8be6b710" class="spinner-border text-info" role="status">
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_6736e03e5bf5bbf0ef55bb312bca5fa0" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0")) {
#               dt = $("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0").dataTable();
#             } else if ($("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0_wrapper").length == 0) {
#               dt = $("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'transactions.0'}, {'title': 'event_time'}, {'title': 'windows'}, {'title': 'pane_info'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '96.13', 2: '2021-02-13 20:13:41.450000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 0}, {1: '8.64', 2: '2021-02-13 20:13:43.162000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 1}, {1: '96.86', 2: '2021-02-13 20:13:44.851000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 2}, {1: '88.24', 2: '2021-02-13 20:13:46.463000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 3}, {1: '11.75', 2: '2021-02-13 20:13:48.083000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 4}, {1: '28.82', 2: '2021-02-13 20:13:49.765000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 5}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0")) {
#               dt = $("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0").dataTable();
#             } else if ($("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0_wrapper").length == 0) {
#               dt = $("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'transactions.0'}, {'title': 'event_time'}, {'title': 'windows'}, {'title': 'pane_info'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '96.13', 2: '2021-02-13 20:13:41.450000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 0}, {1: '8.64', 2: '2021-02-13 20:13:43.162000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 1}, {1: '96.86', 2: '2021-02-13 20:13:44.851000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 2}, {1: '88.24', 2: '2021-02-13 20:13:46.463000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 3}, {1: '11.75', 2: '2021-02-13 20:13:48.083000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 4}, {1: '28.82', 2: '2021-02-13 20:13:49.765000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 5}])
#               .draw('full-hold');
#           });
#         }
#             </script>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_6736e03e5bf5bbf0ef55bb312bca5fa0" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0")) {
#               dt = $("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0").dataTable();
#             } else if ($("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0_wrapper").length == 0) {
#               dt = $("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'transactions.0'}, {'title': 'event_time'}, {'title': 'windows'}, {'title': 'pane_info'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '96.13', 2: '2021-02-13 20:13:41.450000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 0}, {1: '8.64', 2: '2021-02-13 20:13:43.162000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 1}, {1: '96.86', 2: '2021-02-13 20:13:44.851000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 2}, {1: '88.24', 2: '2021-02-13 20:13:46.463000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 3}, {1: '11.75', 2: '2021-02-13 20:13:48.083000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 4}, {1: '28.82', 2: '2021-02-13 20:13:49.765000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 5}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0")) {
#               dt = $("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0").dataTable();
#             } else if ($("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0_wrapper").length == 0) {
#               dt = $("#table_df_6736e03e5bf5bbf0ef55bb312bca5fa0").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'transactions.0'}, {'title': 'event_time'}, {'title': 'windows'}, {'title': 'pane_info'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '96.13', 2: '2021-02-13 20:13:41.450000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 0}, {1: '8.64', 2: '2021-02-13 20:13:43.162000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 1}, {1: '96.86', 2: '2021-02-13 20:13:44.851000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 2}, {1: '88.24', 2: '2021-02-13 20:13:46.463000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 3}, {1: '11.75', 2: '2021-02-13 20:13:48.083000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 4}, {1: '28.82', 2: '2021-02-13 20:13:49.765000+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0: Final ', 0: 5}])
#               .draw('full-hold');
#           });
#         }
#             </script>

# %%
rates = transactions | beam.CombineGlobally(sum).without_defaults()

# %%
ib.show(rates, include_window_info=True)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_682fd3bfd9c6dd5dcbc301fab0261788" class="spinner-border text-info" role="status">
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_ffbf900fe0ed516eca9cff5fe844f8a8" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8")) {
#               dt = $("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8").dataTable();
#             } else if ($("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8_wrapper").length == 0) {
#               dt = $("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'rates.0'}, {'title': 'event_time'}, {'title': 'windows'}, {'title': 'pane_info'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '330.44', 2: '2021-02-13 20:13:49.999999+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0', 0: 0}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8")) {
#               dt = $("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8").dataTable();
#             } else if ($("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8_wrapper").length == 0) {
#               dt = $("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'rates.0'}, {'title': 'event_time'}, {'title': 'windows'}, {'title': 'pane_info'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '330.44', 2: '2021-02-13 20:13:49.999999+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0', 0: 0}])
#               .draw('full-hold');
#           });
#         }
#             </script>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_ffbf900fe0ed516eca9cff5fe844f8a8" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8")) {
#               dt = $("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8").dataTable();
#             } else if ($("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8_wrapper").length == 0) {
#               dt = $("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'rates.0'}, {'title': 'event_time'}, {'title': 'windows'}, {'title': 'pane_info'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '330.44', 2: '2021-02-13 20:13:49.999999+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0', 0: 0}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8")) {
#               dt = $("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8").dataTable();
#             } else if ($("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8_wrapper").length == 0) {
#               dt = $("#table_df_ffbf900fe0ed516eca9cff5fe844f8a8").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'rates.0'}, {'title': 'event_time'}, {'title': 'windows'}, {'title': 'pane_info'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '330.44', 2: '2021-02-13 20:13:49.999999+0000', 3: '2021-02-13 20:13:40.000000+0000 (10s)', 4: 'Pane 0', 0: 0}])
#               .draw('full-hold');
#           });
#         }
#             </script>

# %%
ib.show_graph(p)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_bb99bdac47c951fe08f970b12151458f" class="spinner-border text-info" role="status">
#             </div>
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="363pt" height="923pt"
#  viewBox="0.00 0.00 363.00 922.76" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 918.7636)">
# <title>G</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-918.7636 359,-918.7636 359,4 -4,4"/>
# <!-- [10]: read -->
# <g id="node1" class="node">
# <title>[10]: read</title>
# <polygon fill="none" stroke="#0000ff" points="212.5,-914.7636 142.5,-914.7636 142.5,-878.7636 212.5,-878.7636 212.5,-914.7636"/>
# <text text-anchor="middle" x="177.5" y="-893.0636" font-family="Times,serif" font-size="14.00" fill="#0000ff">[10]: read</text>
# </g>
# <!-- data -->
# <g id="node2" class="node">
# <title>data</title>
# <ellipse fill="none" stroke="#0000ff" cx="177.5" cy="-817.4158" rx="25.1964" ry="25.1964"/>
# <text text-anchor="middle" x="177.5" y="-813.7158" font-family="Times,serif" font-size="14.00" fill="#0000ff">data</text>
# </g>
# <!-- [10]: read&#45;&gt;data -->
# <g id="edge1" class="edge">
# <title>[10]: read&#45;&gt;data</title>
# <path fill="none" stroke="#000000" d="M177.5,-878.7583C177.5,-871.1338 177.5,-861.969 177.5,-853.076"/>
# <polygon fill="#000000" stroke="#000000" points="181.0001,-852.8698 177.5,-842.8698 174.0001,-852.8699 181.0001,-852.8698"/>
# </g>
# <!-- [19]: Map(loads) -->
# <g id="node3" class="node">
# <title>[19]: Map(loads)</title>
# <polygon fill="none" stroke="#0000ff" points="232.5,-756.0681 122.5,-756.0681 122.5,-720.0681 232.5,-720.0681 232.5,-756.0681"/>
# <text text-anchor="middle" x="177.5" y="-734.3681" font-family="Times,serif" font-size="14.00" fill="#0000ff">[19]: Map(loads)</text>
# </g>
# <!-- data&#45;&gt;[19]: Map(loads) -->
# <g id="edge2" class="edge">
# <title>data&#45;&gt;[19]: Map(loads)</title>
# <path fill="none" stroke="#000000" d="M177.5,-791.8729C177.5,-783.7181 177.5,-774.6471 177.5,-766.3119"/>
# <polygon fill="#000000" stroke="#000000" points="181.0001,-766.272 177.5,-756.272 174.0001,-766.2721 181.0001,-766.272"/>
# </g>
# <!-- data_parsed -->
# <g id="node4" class="node">
# <title>data_parsed</title>
# <ellipse fill="none" stroke="#0000ff" cx="177.5" cy="-631.4227" rx="52.7911" ry="52.7911"/>
# <text text-anchor="middle" x="177.5" y="-627.7227" font-family="Times,serif" font-size="14.00" fill="#0000ff">data_parsed</text>
# </g>
# <!-- [19]: Map(loads)&#45;&gt;data_parsed -->
# <g id="edge3" class="edge">
# <title>[19]: Map(loads)&#45;&gt;data_parsed</title>
# <path fill="none" stroke="#000000" d="M177.5,-719.9771C177.5,-712.6454 177.5,-703.7051 177.5,-694.3573"/>
# <polygon fill="#000000" stroke="#000000" points="181.0001,-694.1107 177.5,-684.1108 174.0001,-694.1108 181.0001,-694.1107"/>
# </g>
# <!-- [21]: WindowInto(WindowIntoFn) -->
# <g id="node5" class="node">
# <title>[21]: WindowInto(WindowIntoFn)</title>
# <polygon fill="none" stroke="#0000ff" points="281.5,-542.7774 73.5,-542.7774 73.5,-506.7774 281.5,-506.7774 281.5,-542.7774"/>
# <text text-anchor="middle" x="177.5" y="-521.0774" font-family="Times,serif" font-size="14.00" fill="#0000ff">[21]: WindowInto(WindowIntoFn)</text>
# </g>
# <!-- data_parsed&#45;&gt;[21]: WindowInto(WindowIntoFn) -->
# <g id="edge4" class="edge">
# <title>data_parsed&#45;&gt;[21]: WindowInto(WindowIntoFn)</title>
# <path fill="none" stroke="#000000" d="M177.5,-578.7249C177.5,-569.922 177.5,-561.0963 177.5,-553.2078"/>
# <polygon fill="#000000" stroke="#000000" points="181.0001,-553.1217 177.5,-543.1218 174.0001,-553.1218 181.0001,-553.1217"/>
# </g>
# <!-- windowed -->
# <g id="node6" class="node">
# <title>windowed</title>
# <ellipse fill="none" stroke="#0000ff" cx="177.5" cy="-423.3316" rx="47.3916" ry="47.3916"/>
# <text text-anchor="middle" x="177.5" y="-419.6316" font-family="Times,serif" font-size="14.00" fill="#0000ff">windowed</text>
# </g>
# <!-- [21]: WindowInto(WindowIntoFn)&#45;&gt;windowed -->
# <g id="edge5" class="edge">
# <title>[21]: WindowInto(WindowIntoFn)&#45;&gt;windowed</title>
# <path fill="none" stroke="#000000" d="M177.5,-506.6409C177.5,-499.2748 177.5,-490.3187 177.5,-481.0448"/>
# <polygon fill="#000000" stroke="#000000" points="181.0001,-480.917 177.5,-470.9171 174.0001,-480.9171 181.0001,-480.917"/>
# </g>
# <!-- [23]: Map(&lt;lambda at &lt;ipython&#45;input&#45;23&#45;a209aed29b2f&gt;:1&gt;) -->
# <g id="node7" class="node">
# <title>[23]: Map(&lt;lambda at &lt;ipython&#45;input&#45;23&#45;a209aed29b2f&gt;:1&gt;)</title>
# <polygon fill="none" stroke="#0000ff" points="355,-339.8858 0,-339.8858 0,-303.8858 355,-303.8858 355,-339.8858"/>
# <text text-anchor="middle" x="177.5" y="-318.1858" font-family="Times,serif" font-size="14.00" fill="#0000ff">[23]: Map(&lt;lambda at &lt;ipython&#45;input&#45;23&#45;a209aed29b2f&gt;:1&gt;)</text>
# </g>
# <!-- windowed&#45;&gt;[23]: Map(&lt;lambda at &lt;ipython&#45;input&#45;23&#45;a209aed29b2f&gt;:1&gt;) -->
# <g id="edge6" class="edge">
# <title>windowed&#45;&gt;[23]: Map(&lt;lambda at &lt;ipython&#45;input&#45;23&#45;a209aed29b2f&gt;:1&gt;)</title>
# <path fill="none" stroke="#000000" d="M177.5,-375.8759C177.5,-367.0838 177.5,-358.1601 177.5,-350.1676"/>
# <polygon fill="#000000" stroke="#000000" points="181.0001,-349.9455 177.5,-339.9455 174.0001,-349.9456 181.0001,-349.9455"/>
# </g>
# <!-- transactions -->
# <g id="node8" class="node">
# <title>transactions</title>
# <ellipse fill="none" stroke="#0000ff" cx="177.5" cy="-215.2405" rx="52.7911" ry="52.7911"/>
# <text text-anchor="middle" x="177.5" y="-211.5405" font-family="Times,serif" font-size="14.00" fill="#0000ff">transactions</text>
# </g>
# <!-- [23]: Map(&lt;lambda at &lt;ipython&#45;input&#45;23&#45;a209aed29b2f&gt;:1&gt;)&#45;&gt;transactions -->
# <g id="edge7" class="edge">
# <title>[23]: Map(&lt;lambda at &lt;ipython&#45;input&#45;23&#45;a209aed29b2f&gt;:1&gt;)&#45;&gt;transactions</title>
# <path fill="none" stroke="#000000" d="M177.5,-303.7949C177.5,-296.4631 177.5,-287.5229 177.5,-278.1751"/>
# <polygon fill="#000000" stroke="#000000" points="181.0001,-277.9285 177.5,-267.9285 174.0001,-277.9286 181.0001,-277.9285"/>
# </g>
# <!-- [25]: CombineGlobally(sum) -->
# <g id="node9" class="node">
# <title>[25]: CombineGlobally(sum)</title>
# <polygon fill="none" stroke="#0000ff" points="265.5,-126.5952 89.5,-126.5952 89.5,-90.5952 265.5,-90.5952 265.5,-126.5952"/>
# <text text-anchor="middle" x="177.5" y="-104.8952" font-family="Times,serif" font-size="14.00" fill="#0000ff">[25]: CombineGlobally(sum)</text>
# </g>
# <!-- transactions&#45;&gt;[25]: CombineGlobally(sum) -->
# <g id="edge8" class="edge">
# <title>transactions&#45;&gt;[25]: CombineGlobally(sum)</title>
# <path fill="none" stroke="#000000" d="M177.5,-162.5427C177.5,-153.7397 177.5,-144.9141 177.5,-137.0256"/>
# <polygon fill="#000000" stroke="#000000" points="181.0001,-136.9395 177.5,-126.9395 174.0001,-136.9396 181.0001,-136.9395"/>
# </g>
# <!-- rates -->
# <g id="node10" class="node">
# <title>rates</title>
# <ellipse fill="none" stroke="#0000ff" cx="177.5" cy="-27.2976" rx="27.0966" ry="27.0966"/>
# <text text-anchor="middle" x="177.5" y="-23.5976" font-family="Times,serif" font-size="14.00" fill="#0000ff">rates</text>
# </g>
# <!-- [25]: CombineGlobally(sum)&#45;&gt;rates -->
# <g id="edge9" class="edge">
# <title>[25]: CombineGlobally(sum)&#45;&gt;rates</title>
# <path fill="none" stroke="#000000" d="M177.5,-90.5526C177.5,-83.0211 177.5,-73.9716 177.5,-65.1033"/>
# <polygon fill="#000000" stroke="#000000" points="181.0001,-64.8779 177.5,-54.8779 174.0001,-64.878 181.0001,-64.8779"/>
# </g>
# </g>
# </svg>
